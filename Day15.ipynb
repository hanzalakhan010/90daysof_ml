# %% [markdown]
# Agenda
#     Hierarchical Clustering
#     VIsuals(dendogram)
#     Create a dendograg and identify optimal no of clusters
#     fit AgglomerativeClustering with that no of clusters

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import  load_iris
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score,davies_bouldin_score
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
data = load_iris()
X = data.data
y = data.target

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
linked = linkage(X_scaled,method='ward')
plt.figure(figsize=(10, 7))
dendrogram(linked)
plt.title("Dendrogram for Iris Dataset")
plt.show()

# %%
# Perform hierarchical clustering

clustering = AgglomerativeClustering(n_clusters=2)
y_pred = clustering.fit_predict(X_scaled)

# %%
silhouette = silhouette_score(X_scaled,y_pred)
print(f"Silhouette Score: {silhouette}")
# Out:
# Silhouette Score: 0.5770346019475989

# %%
d = davies_bouldin_score(X_scaled,y_pred)
print(f'Davies Bouldin Score : {d}')
# Out:
# Davies Bouldin Score : 0.5916560992933364

# %%
cluster_purity = sum(y_pred == y) / len(y)
print(f'Cluster Purity: {cluster_purity}')
# Out:
# Cluster Purity: 0.006666666666666667
