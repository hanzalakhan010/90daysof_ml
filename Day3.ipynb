# %%
import pandas as pd
import seaborn as sns
# df = pd.read_csv('./datasets/landslides.csv')
# df = pd.read_csv('./datasets/volcano.csv')
# df = pd.read_csv('./datasets/iris/Iris.csv')
df = pd.read_csv('./datasets/titanic.csv')

df.head()

# %%
# df['date'].dtype
df['date_parsed'] = pd.to_datetime(df['date'],format="%m/%d/%y")
df['date_parsed'].dtype

# %%
df["date_parsed"].dt.month

# %%
month_of_landslides = df['date_parsed'].dt.month.dropna()
sns.displot(month_of_landslides,bins =12 )

# %%
day_of_landslides = df['date_parsed'].dt.day.dropna()
sns.displot(day_of_landslides,kde = False,bins = 31)

# %%
df['Last Known Eruption'].sample(5)

# %%
encoded_df = pd.get_dummies(df,columns = ['Species'])
encoded_df

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Age'].median()
# Out:
# np.float64(28.0)

# %%
df = df.dropna(subset=['Embarked'])
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_encoded = pd.get_dummies(df,columns=['Embarked'])
df_encoded
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.displot(df['Age'])

# %%
'''
Summary

What challenges did I face while cleaning the data?
    [during working on volcanoes dataset dates are in bce and ce which I may need to first filter first]
    []

How did I handle missing values and outliers?
    [used fillna(df['Age'].median) to fill missing ages with median of column age]
    [I could also have used mean]
    [to remove outliers I would need to first find lower and upper boound using q1 - 1.5(iqr) and q3 + 1.5(iqr)
    and then I will filter the values in age column using simmle selection and set them to filtered_age in dataset]
    

Why did you choose specific techniques?


'''
